# %%
import pandas as pd
import os

# %%
df_competence = pd.read_csv(os.path.join(os.getcwd(), '..', 'poc-referentiel-competence', 'cigref compétence.csv'), delimiter=';')

df_competence
# Out:
#    domaine de compétence                                      compétence_id  \
# 0           A. Planifier  A.1. Systèmes d’information et alignement stra...
# 1           A. Planifier                  A.5. Conception de l'architecture
# 2           A. Planifier                   A.6. Conception des applications
# 3           A. Planifier                          A.7. Veille technologique
# 4           A. Planifier                                    A.9. Innovation
# 5          B. Développer    B.1. Conception et développement d'applications
# 6          B. Développer                                         B.3. Tests
# 7          B. Développer                B.5. Production de la documentation
# 8          B. Développer                   B.6. Ingénierie des systèmes TIC
# 9           C. Exploiter                        C.3. Fourniture de services
# 10          C. Exploiter                         C.4. Gestion des problèmes
# 11          D. Faciliter  D.1. Développement d'une stratégie de sécurité...
# 12          D. Faciliter  D.2. Développement d'une stratégie pour la qua...
# 13          D. Faciliter           D.3. Prestation de services de formation
# 14          D. Faciliter                D.7. Science des données et analyse
# 15          D. Faciliter  D.10. Gestion de l'information et de la connai...
# 16          D. Faciliter                   D.11. Identification des besoins
# 17              E. Gérer                    E.1. Développement prévisionnel
# 18              E. Gérer                           E.3. Gestion des risques
# 19              E. Gérer                 E.4. Gestion de la relation client
# 20              E. Gérer                    E.5. Amélioration des processus
# 21              E. Gérer                 E.6. Gestion de la qualité des TIC
# 22              E. Gérer                E.7. Gestion des changements métier
# 23              E. Gérer       E.8. Gestion de la sécurité de l'information
# 24              E. Gérer        E.9. Gouvernance des systèmes d'information
#
#                                            compétence
# 0   Anticipe les besoins métier à long terme, infl...
# 1   Définit, détaille, actualise et met en place u...
# 2   Analyse, définit, actualise et met en place un...
# 3   Étudie en détail les dernières innovations tec...
# 4   Envisage des solutions créatives pour élaborer...
# 5   Interprète les techniques de conception pour d...
# 6   Met au point et exécute des procédures d'essai...
# 7   Produit des documents en intégrant des informa...
# 8   Construit les réseaux/connexions de réseau, le...
# 9   Assure la fourniture des services en fonction ...
# 10  Gère le cycle de vie des incidents et des prob...
# 11  Définit et rend applicable une stratégie d'org...
# 12  Définit, améliore et précise une stratégie for...
# 13  Définit et met en place une politique de forma...
# 14  Utilise et met en application des techniques d...
# 15  Identifie les informations et les connaissance...
# 16  Écoute attentivement les clients internes et e...
# 17  Interprète les besoins du marché et évalue l'a...
# 18  Met en œuvre la gestion des risques dans les s...
# 19  Met en place de bonnes relations de travail au...
# 20  Mesure l'efficacité des approches de processus...
# 21  Met en œuvre une politique de qualité des TIC ...
# 22  Évalue les implications de la transformation n...
# 23  Gère la politique de sécurité de l'information...
# 24  Définit, déploie et contrôle la gestion des sy...

# %%
df = pd.read_csv(os.path.join(os.getcwd(), '..', 'poc-referentiel-competence', 'cigref.csv'), delimiter=';')

df
# Out:
#                                 profil métier  \
# 0                             DATA SCIENTISTE
# 1                             DATA SCIENTISTE
# 2                             DATA SCIENTISTE
# 3                             DATA SCIENTISTE
# 4                             DATA SCIENTISTE
# 5                             DATA SCIENTISTE
# 6                             DATA SCIENTISTE
# 7                               DATA ANALYSTE
# 8                               DATA ANALYSTE
# 9                               DATA ANALYSTE
# 10                              DATA ANALYSTE
# 11                              DATA ANALYSTE
# 12                              DATA ANALYSTE
# 13                              DATA ANALYSTE
# 14                              DATA ANALYSTE
# 15                              DATA ANALYSTE
# 16                         CHIEF DATA OFFICER
# 17                         CHIEF DATA OFFICER
# 18                         CHIEF DATA OFFICER
# 19                         CHIEF DATA OFFICER
# 20                         CHIEF DATA OFFICER
# 21                         CHIEF DATA OFFICER
# 22                         CHIEF DATA OFFICER
# 23                         CHIEF DATA OFFICER
# 24                         CHIEF DATA OFFICER
# 25                              DATA ENGINEER
# 26                              DATA ENGINEER
# 27                              DATA ENGINEER
# 28                              DATA ENGINEER
# 29                              DATA ENGINEER
# 30                              DATA ENGINEER
# 31                              DATA ENGINEER
# 32                              DATA ENGINEER
# 33                              DATA ENGINEER
# 34                              DATA ENGINEER
# 35  DÉLÉGUÉ À LA PROTECTION DES DONNÉES (DPO)
# 36  DÉLÉGUÉ À LA PROTECTION DES DONNÉES (DPO)
# 37  DÉLÉGUÉ À LA PROTECTION DES DONNÉES (DPO)
# 38  DÉLÉGUÉ À LA PROTECTION DES DONNÉES (DPO)
# 39  DÉLÉGUÉ À LA PROTECTION DES DONNÉES (DPO)
# 40  DÉLÉGUÉ À LA PROTECTION DES DONNÉES (DPO)
# 41                             DATA ARCHITECT
# 42                             DATA ARCHITECT
# 43                             DATA ARCHITECT
# 44                             DATA ARCHITECT
# 45                             DATA ARCHITECT
# 46                             DATA ARCHITECT
# 47                             DATA ARCHITECT
#
#                                         compétence_id  niveau
# 0                           A.7. Veille technologique       4
# 1                                     A.9. Innovation       4
# 2                 D.7. Science des données et analyse       4
# 3   D.10. Gestion de l'information et de la connai...       4
# 4                    D.11. Identification des besoins       5
# 5                     E.1. Développement prévisionnel       3
# 6                  E.6. Gestion de la qualité des TIC       4
# 7                                     A.9. Innovation       4
# 8     B.1. Conception et développement d'applications       2
# 9                                          B.3. Tests       2
# 10                B.5. Production de la documentation       3
# 11                D.7. Science des données et analyse       3
# 12  D.10. Gestion de l'information et de la connai...       4
# 13                   D.11. Identification des besoins       3
# 14                    E.1. Développement prévisionnel       3
# 15                 E.4. Gestion de la relation client       3
# 16  A.1. Systèmes d’information et alignement stra...       5
# 17                                    A.9. Innovation       5
# 18  D.1. Développement d'une stratégie de sécurité...       4
# 19  D.2. Développement d'une stratégie pour la qua...       5
# 20  D.10. Gestion de l'information et de la connai...       5
# 21                    E.1. Développement prévisionnel       4
# 22                 E.4. Gestion de la relation client       4
# 23                E.7. Gestion des changements métier       5
# 24        E.9. Gouvernance des systèmes d'information       5
# 25                  A.5. Conception de l'architecture       3
# 26                          A.7. Veille technologique       3
# 27                   B.6. Ingénierie des systèmes TIC       3
# 28                        C.3. Fourniture de services       3
# 29                         C.4. Gestion des problèmes       3
# 30                D.7. Science des données et analyse       2
# 31  D.10. Gestion de l'information et de la connai...       3
# 32                           E.3. Gestion des risques       2
# 33                 E.6. Gestion de la qualité des TIC       3
# 34       E.8. Gestion de la sécurité de l'information       3
# 35                B.5. Production de la documentation       2
# 36  D.1. Développement d'une stratégie de sécurité...       4
# 37           D.3. Prestation de services de formation       3
# 38  D.10. Gestion de l'information et de la connai...       3
# 39                           E.3. Gestion des risques       3
# 40       E.8. Gestion de la sécurité de l'information       4
# 41                  A.5. Conception de l'architecture       5
# 42                   A.6. Conception des applications       2
# 43  D.2. Développement d'une stratégie pour la qua...       4
# 44                           E.3. Gestion des risques       4
# 45                    E.5. Amélioration des processus       3
# 46                E.7. Gestion des changements métier       3
# 47        E.9. Gouvernance des systèmes d'information       4

# %%
df_res = pd.merge(df, df_competence,how='left', left_on='compétence_id', right_on='compétence_id')
df_res.columns
# Out:
# Index(['profil métier', 'compétence_id', 'niveau', 'domaine de compétence',
#        'compétence'],
#       dtype='object')

# %%
df_res = df_res[['profil métier', 'domaine de compétence', 'compétence_id', 'compétence', 'niveau']]

df_res
# Out:
#                                 profil métier domaine de compétence  \
# 0                             DATA SCIENTISTE          A. Planifier
# 1                             DATA SCIENTISTE          A. Planifier
# 2                             DATA SCIENTISTE          D. Faciliter
# 3                             DATA SCIENTISTE          D. Faciliter
# 4                             DATA SCIENTISTE          D. Faciliter
# 5                             DATA SCIENTISTE              E. Gérer
# 6                             DATA SCIENTISTE              E. Gérer
# 7                               DATA ANALYSTE          A. Planifier
# 8                               DATA ANALYSTE         B. Développer
# 9                               DATA ANALYSTE         B. Développer
# 10                              DATA ANALYSTE         B. Développer
# 11                              DATA ANALYSTE          D. Faciliter
# 12                              DATA ANALYSTE          D. Faciliter
# 13                              DATA ANALYSTE          D. Faciliter
# 14                              DATA ANALYSTE              E. Gérer
# 15                              DATA ANALYSTE              E. Gérer
# 16                         CHIEF DATA OFFICER          A. Planifier
# 17                         CHIEF DATA OFFICER          A. Planifier
# 18                         CHIEF DATA OFFICER          D. Faciliter
# 19                         CHIEF DATA OFFICER          D. Faciliter
# 20                         CHIEF DATA OFFICER          D. Faciliter
# 21                         CHIEF DATA OFFICER              E. Gérer
# 22                         CHIEF DATA OFFICER              E. Gérer
# 23                         CHIEF DATA OFFICER              E. Gérer
# 24                         CHIEF DATA OFFICER              E. Gérer
# 25                              DATA ENGINEER          A. Planifier
# 26                              DATA ENGINEER          A. Planifier
# 27                              DATA ENGINEER         B. Développer
# 28                              DATA ENGINEER          C. Exploiter
# 29                              DATA ENGINEER          C. Exploiter
# 30                              DATA ENGINEER          D. Faciliter
# 31                              DATA ENGINEER          D. Faciliter
# 32                              DATA ENGINEER              E. Gérer
# 33                              DATA ENGINEER              E. Gérer
# 34                              DATA ENGINEER              E. Gérer
# 35  DÉLÉGUÉ À LA PROTECTION DES DONNÉES (DPO)         B. Développer
# 36  DÉLÉGUÉ À LA PROTECTION DES DONNÉES (DPO)          D. Faciliter
# 37  DÉLÉGUÉ À LA PROTECTION DES DONNÉES (DPO)          D. Faciliter
# 38  DÉLÉGUÉ À LA PROTECTION DES DONNÉES (DPO)          D. Faciliter
# 39  DÉLÉGUÉ À LA PROTECTION DES DONNÉES (DPO)              E. Gérer
# 40  DÉLÉGUÉ À LA PROTECTION DES DONNÉES (DPO)              E. Gérer
# 41                             DATA ARCHITECT          A. Planifier
# 42                             DATA ARCHITECT          A. Planifier
# 43                             DATA ARCHITECT          D. Faciliter
# 44                             DATA ARCHITECT              E. Gérer
# 45                             DATA ARCHITECT              E. Gérer
# 46                             DATA ARCHITECT              E. Gérer
# 47                             DATA ARCHITECT              E. Gérer
#
#                                         compétence_id  \
# 0                           A.7. Veille technologique
# 1                                     A.9. Innovation
# 2                 D.7. Science des données et analyse
# 3   D.10. Gestion de l'information et de la connai...
# 4                    D.11. Identification des besoins
# 5                     E.1. Développement prévisionnel
# 6                  E.6. Gestion de la qualité des TIC
# 7                                     A.9. Innovation
# 8     B.1. Conception et développement d'applications
# 9                                          B.3. Tests
# 10                B.5. Production de la documentation
# 11                D.7. Science des données et analyse
# 12  D.10. Gestion de l'information et de la connai...
# 13                   D.11. Identification des besoins
# 14                    E.1. Développement prévisionnel
# 15                 E.4. Gestion de la relation client
# 16  A.1. Systèmes d’information et alignement stra...
# 17                                    A.9. Innovation
# 18  D.1. Développement d'une stratégie de sécurité...
# 19  D.2. Développement d'une stratégie pour la qua...
# 20  D.10. Gestion de l'information et de la connai...
# 21                    E.1. Développement prévisionnel
# 22                 E.4. Gestion de la relation client
# 23                E.7. Gestion des changements métier
# 24        E.9. Gouvernance des systèmes d'information
# 25                  A.5. Conception de l'architecture
# 26                          A.7. Veille technologique
# 27                   B.6. Ingénierie des systèmes TIC
# 28                        C.3. Fourniture de services
# 29                         C.4. Gestion des problèmes
# 30                D.7. Science des données et analyse
# 31  D.10. Gestion de l'information et de la connai...
# 32                           E.3. Gestion des risques
# 33                 E.6. Gestion de la qualité des TIC
# 34       E.8. Gestion de la sécurité de l'information
# 35                B.5. Production de la documentation
# 36  D.1. Développement d'une stratégie de sécurité...
# 37           D.3. Prestation de services de formation
# 38  D.10. Gestion de l'information et de la connai...
# 39                           E.3. Gestion des risques
# 40       E.8. Gestion de la sécurité de l'information
# 41                  A.5. Conception de l'architecture
# 42                   A.6. Conception des applications
# 43  D.2. Développement d'une stratégie pour la qua...
# 44                           E.3. Gestion des risques
# 45                    E.5. Amélioration des processus
# 46                E.7. Gestion des changements métier
# 47        E.9. Gouvernance des systèmes d'information
#
#                                            compétence  niveau
# 0   Étudie en détail les dernières innovations tec...       4
# 1   Envisage des solutions créatives pour élaborer...       4
# 2   Utilise et met en application des techniques d...       4
# 3   Identifie les informations et les connaissance...       4
# 4   Écoute attentivement les clients internes et e...       5
# 5   Interprète les besoins du marché et évalue l'a...       3
# 6   Met en œuvre une politique de qualité des TIC ...       4
# 7   Envisage des solutions créatives pour élaborer...       4
# 8   Interprète les techniques de conception pour d...       2
# 9   Met au point et exécute des procédures d'essai...       2
# 10  Produit des documents en intégrant des informa...       3
# 11  Utilise et met en application des techniques d...       3
# 12  Identifie les informations et les connaissance...       4
# 13  Écoute attentivement les clients internes et e...       3
# 14  Interprète les besoins du marché et évalue l'a...       3
# 15  Met en place de bonnes relations de travail au...       3
# 16  Anticipe les besoins métier à long terme, infl...       5
# 17  Envisage des solutions créatives pour élaborer...       5
# 18  Définit et rend applicable une stratégie d'org...       4
# 19  Définit, améliore et précise une stratégie for...       5
# 20  Identifie les informations et les connaissance...       5
# 21  Interprète les besoins du marché et évalue l'a...       4
# 22  Met en place de bonnes relations de travail au...       4
# 23  Évalue les implications de la transformation n...       5
# 24  Définit, déploie et contrôle la gestion des sy...       5
# 25  Définit, détaille, actualise et met en place u...       3
# 26  Étudie en détail les dernières innovations tec...       3
# 27  Construit les réseaux/connexions de réseau, le...       3
# 28  Assure la fourniture des services en fonction ...       3
# 29  Gère le cycle de vie des incidents et des prob...       3
# 30  Utilise et met en application des techniques d...       2
# 31  Identifie les informations et les connaissance...       3
# 32  Met en œuvre la gestion des risques dans les s...       2
# 33  Met en œuvre une politique de qualité des TIC ...       3
# 34  Gère la politique de sécurité de l'information...       3
# 35  Produit des documents en intégrant des informa...       2
# 36  Définit et rend applicable une stratégie d'org...       4
# 37  Définit et met en place une politique de forma...       3
# 38  Identifie les informations et les connaissance...       3
# 39  Met en œuvre la gestion des risques dans les s...       3
# 40  Gère la politique de sécurité de l'information...       4
# 41  Définit, détaille, actualise et met en place u...       5
# 42  Analyse, définit, actualise et met en place un...       2
# 43  Définit, améliore et précise une stratégie for...       4
# 44  Met en œuvre la gestion des risques dans les s...       4
# 45  Mesure l'efficacité des approches de processus...       3
# 46  Évalue les implications de la transformation n...       3
# 47  Définit, déploie et contrôle la gestion des sy...       4

# %%
df_res[df_res["compétence"].isna()]
# Out:
# Empty DataFrame
# Columns: [profil métier, domaine de compétence, compétence_id, compétence, niveau]
# Index: []
