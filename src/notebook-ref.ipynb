# %%
import pandas as pd
import os

# %%
df_competence = pd.read_csv(os.path.join(os.getcwd(), '..', 'poc-referentiel-competence', 'cigref compétence.csv'), delimiter=';')

df_competence
# Out:
#   domaine de compétence                                      compétence_id  \
# 0          A. Planifier                           A.7 Veille technologique
# 1          A. Planifier                                     A.9 Innovation
# 2          D. Faciliter                D.7. Science des données et analyse
# 3          D. Faciliter  D.10. Gestion de l'information et de la connai...
# 4          D. Faciliter                   D.11. Identification des besoins
# 5              E. Gérer                    E.1. Développement prévisionnel
# 6              E. Gérer                 E.6. Gestion de la qualité des TIC
#
#                                           compétence
# 0  Étudie en détail les dernières innovations tec...
# 1  Envisage des solutions créatives pour élaborer...
# 2  Utilise et met en application des techniques d...
# 3  Identifie les informations et les connaissance...
# 4  Écoute attentivement les clients internes et e...
# 5  Interprète les besoins du marché et évalue l'a...
# 6  Met en œuvre une politique de qualité des TIC ...

# %%
df = pd.read_csv(os.path.join(os.getcwd(), '..', 'poc-referentiel-competence', 'cigref.csv'), delimiter=';')

df
# Out:
#      profil métier domaine de compétence  \
# 0  DATA SCIENTISTE          A. Planifier
# 1  DATA SCIENTISTE          A. Planifier
# 2  DATA SCIENTISTE          D. Faciliter
# 3  DATA SCIENTISTE          D. Faciliter
# 4  DATA SCIENTISTE          D. Faciliter
# 5  DATA SCIENTISTE              E. Gérer
# 6  DATA SCIENTISTE              E. Gérer
#
#                                        compétence_id  niveau  \
# 0                           A.7 Veille technologique       4
# 1                                     A.9 Innovation       4
# 2                D.7. Science des données et analyse       4
# 3  D.10. Gestion de l'information et de la connai...       4
# 4                   D.11. Identification des besoins       5
# 5                    E.1. Développement prévisionnel       3
# 6                 E.6. Gestion de la qualité des TIC       4
#
#                                         niveau_texte
# 0  Valide les technologies nouvelles et émergente...
# 1  Adopte un mode de pensée indépendant et une co...
# 2  Interprète les résultats de l'analyse des donn...
# 3  Intègre et synthétise les informations provena...
# 4  Guide et soutient les clients dans leur prise ...
# 5  Exploite des aptitudes pour fournir des prévis...
# 6  Évalue et estime le niveau d'exigence qualité ...
